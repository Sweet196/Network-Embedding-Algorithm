# %% [markdown]
# ### Circle Dataset

# %%
# %matplotlib inline
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
from node import Node, Graph
import numpy as np

# 生成 make_moons 数据集
X, y = make_circles(n_samples=2000, noise=0.1
                  , random_state=42, factor=0.3)
# X是每个点的坐标(x, y)，y是每个点的label
nodes = []
index = 0
for df, label in zip(X, y):
    nodes.append(Node(df, label, index))
    index += 1
# scatter
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title("moon_dataset visulization")
plt.show()

# %% [markdown]
# ### 构建邻接矩阵

# %%
DISTANCE = 0.5
graph = Graph(nodes, distance=DISTANCE)
adjacency_matrix = np.array(graph.get_adjacency_matrix())
print("邻接矩阵：", adjacency_matrix.shape)

#根据邻接矩阵获取所有的二元组，如：[(0, 1), (0, 2), (1, 2)]
edges = graph.get_edges()
print(f"Distance={DISTANCE}, 构建了{len(edges)}条边")
# Out:
# 邻接矩阵： (2000, 2000)
# Distance=0.5, 构建了403598条边

# %% [markdown]
# ### DeepWalk

# %% [markdown]
# #### Deepwalk策略定义

# %%
# deepwalk的游走策略
import networkx as nx
import gensim
import random

def deepwalk(graph, walk_length = 60, num_walks = 200, dim = 32):
    # 生成随机游走序列
    walks = []
    for _ in range(num_walks):
        node = random.choice(list(graph.nodes))
        walk = [node]
        while len(walk) < walk_length:
            neighbors = list(graph[node])
            next_node = neighbors[random.randint(0, len(neighbors) - 1)] if neighbors else node
            walk.append(next_node)
            node = next_node
        walks.append(walk)
    # print(walks, end = '\n')

    # 使用 gensim 的 Word2Vec 训练嵌入向量
    sentences = [list(map(str, walk)) for walk in walks]
    # for walk in walks:
    #     print(walk)
    # print(sentences)
    model = gensim.models.Word2Vec(sentences, vector_size=dim, window=walk_length, min_count=1, sg=1)
    node2vec = {str(node): model.wv[str(node)] if str(node) in model.wv else None for node in graph.nodes}
    # for node in graph.nodes:
        # print(node, model.wv[str(node)])
    return node2vec

# %% [markdown]
# #### Deepwalk嵌入，取两维简单做个可视化

# %%
nx = graph.to_nx()
# print(nx.nodes)
embeddings = deepwalk(nx)
# embeddings

# 随便取两个维度看看
x = [embedding[0] for embedding in list(embeddings.values()) if embedding is not None]
y = [embedding[1] for embedding in list(embeddings.values()) if embedding is not None]



label = [node.label for node in nodes if(embeddings[str(node.index)] is not None)]

# 创建散点图
plt.scatter(x, y, c=label)
plt.title("DeepWalk-Make_Circle_Embedding")
# 显示图形
plt.show()

# %% [markdown]
# #### PCA降维，降到两维后做可视化

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# 先drop掉None
embeddings = {key: value for key, value in embeddings.items() if value is not None}
# 假设embeddings是一个字典，其中包含嵌入值
embeddings_value = list(embeddings.values())

# 使用PCA进行降维
pca = PCA(n_components=2)
pca.fit(embeddings_value)
X_pca = pca.transform(embeddings_value)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=label)
plt.title("DeepWalk-Make_Circle_PCA")
plt.show()

# %% [markdown]
# ### Node2Vec

# %% [markdown]
# #### Node2Vec算法定义

# %%
import networkx as nx
import gensim
import random

def node2vec(graph, walk_length=60, num_walks=200, p=1.0, q=1.0, dim=32):
    # Generate random walk sequences
    walks = []
    for _ in range(num_walks):
        node = random.choice(list(graph.nodes))
        walk = [node]
        while len(walk) < walk_length:
            neighbors = list(graph.neighbors(node))
            if len(neighbors) > 0:
                if len(walk) == 1 or random.random() < p:
                    # Choose a neighbor at random with probability P
                    next_node = random.choice(neighbors)
                else:
                    # Choose a neighbor with probability proportional to the inverse of the square of the distance to the previous node
                    weights = [1.0 / q if n == walk[-1] else 1.0 for n in neighbors]
                    next_node = random.choices(neighbors, weights)[0]
                walk.append(next_node)
                node = next_node
            else:
                break
        walks.append(walk)

    # Use gensim's Word2Vec to train embedding vectors
    sentences = [list(map(str, walk)) for walk in walks]
    model = gensim.models.Word2Vec(sentences, vector_size=dim, window=walk_length, min_count=1, sg=1)
    node2vec = {str(node): model.wv[str(node)] if str(node) in model.wv else None for node in graph.nodes}
    return node2vec

# %%
nx = graph.to_nx()
# print(nx.nodes)
embeddings = node2vec(nx)
# embeddings

# 随便取两个维度看看
x = [embedding[0] for embedding in list(embeddings.values()) if embedding is not None]
y = [embedding[1] for embedding in list(embeddings.values()) if embedding is not None]



label = [node.label for node in nodes if(embeddings[str(node.index)] is not None)]

# 创建散点图
plt.scatter(x, y, c=label)
plt.title("Node2Vec-Make_Circle_Embedding")
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# 先drop掉None
embeddings = {key: value for key, value in embeddings.items() if value is not None}
# 假设embeddings是一个字典，其中包含嵌入值
embeddings_value = list(embeddings.values())

# 使用PCA进行降维
pca = PCA(n_components=2)
pca.fit(embeddings_value)
X_pca = pca.transform(embeddings_value)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=label)
plt.title("Node2Vec-Make_Circle_PCA")
plt.show()

# %% [markdown]
# ### GIN

# %%
import os
import numpy as np
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
from scipy.sparse import csr_matrix
import networkx as nx

from scipy.linalg import orthogonal_procrustes

import torch
import torch.optim as optim
from torch_geometric.data import Data

from sklearn.manifold import TSNE
from sklearn.datasets import make_circles  # 导入make_moons函数

from util import Net, GIN, GAT, stationary, reconstruct, dG


np.random.seed(0)
torch.manual_seed(0)

n = 2000
m = 500

# 导入moon数据集
x, y = make_circles(n_samples=n, noise=0.1, random_state=42, factor=0.3) 
# 分割训练集和测试机
n_train = int(n * 0.7)
train_ind = torch.randperm(n)[:n_train]
test_ind = torch.LongTensor(list(set(np.arange(n)) - set(train_ind.tolist())))
# K = int(np.sqrt(n) * np.log2(n) / 10) #作为隐藏输入
D = pairwise_distances(x)# 邻接距离矩阵
# 二值化，得到邻接矩阵
A_binary = np.where(D <= DISTANCE, 1, 0)
# A_binary
# 获得所有的边，二元组格式
row_indices, col_indices = np.where(A_binary == 1)
edges = list(zip(row_indices, col_indices))

# 转为tensor
x = torch.tensor(x, dtype=torch.float)
y = torch.tensor(y, dtype=torch.long)
edges = torch.tensor(edges, dtype=torch.long).t().contiguous()
data = Data(x=x, y=y, edge_index=edges)
print(data)

# 喂到GIN网络中
net = GIN(m)
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.train()
for epoch in range(100):
    ind = torch.eye(n)[:, torch.randperm(n)[:m]]
    # 将节点选择矩阵与特征矩阵连接在一起
    X_extended = torch.hstack([x, ind])
    data = Data(x=X_extended, edge_index=edges)
    rec = net(data) # reconstruct
    loss = dG(x[train_ind], rec[train_ind]) #train loss
    print(f'Epoch {epoch + 1}, Loss: {float(loss)}')
    optimizer.zero_grad() # zero gradient
    loss.backward()
    optimizer.step()

R, _ = orthogonal_procrustes(x.numpy(), rec.detach().numpy())
rec_GIN = rec.detach().numpy() @ R.T
loss_GIN = float(dG(x, rec))
# 创建图形
fig, ax = plt.subplots(1, 2, figsize=(14, 4))
# ax两个画布
ax[0].scatter(x[:, 0], x[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_facecolor('#eeeeee')
txt = ax[0].text(0.05, 0.05, 'Ground Truth', color='k', fontsize=14, weight='bold', transform=ax[0].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='#eeeeee')])

# 绘制 GIN 网络的重构结果
ax[1].scatter(rec_GIN[:, 0], rec_GIN[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[1].set_xticks([])
ax[1].set_yticks([])
txt = ax[1].text(0.05, 0.05, f'GIN $d_G = {loss_GIN:.2f}$', color='k', fontsize=14, weight='bold', transform=ax[1].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='w')])

fig.subplots_adjust()

if not os.path.exists('imgs'):
    os.mkdir('imgs')

fig.savefig('imgs/semi_circle_GIN.png', bbox_inches='tight', dpi=300)

plt.show()
# Out:
# Data(x=[2000, 2], edge_index=[2, 809196], y=[2000])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 1, Loss: 0.551426887512207
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 2, Loss: 0.5597957968711853
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 3, Loss: 0.5518079996109009
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 4, Loss: 0.6057630181312561
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 5, Loss: 0.5354425311088562
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 6, Loss: 1.060469388961792
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 7, Loss: 0.5099139213562012
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 8, Loss: 0.5445379018783569
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 9, Loss: 0.5633862614631653
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 10, Loss: 0.5548831224441528
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 11, Loss: 0.5514828562736511
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 12, Loss: 0.5634026527404785
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 13, Loss: 0.552183985710144
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 14, Loss: 0.5502350926399231
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 15, Loss: 0.5529886484146118
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 16, Loss: 0.5502852201461792
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 17, Loss: 0.5480323433876038
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 18, Loss: 0.5473588109016418
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 19, Loss: 0.5464403629302979
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 20, Loss: 0.5451912879943848
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 21, Loss: 0.5419172644615173
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 22, Loss: 0.535927414894104
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 23, Loss: 0.5275173783302307
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 24, Loss: 0.518211305141449
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 25, Loss: 0.5016624331474304
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 26, Loss: 0.47461700439453125
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 27, Loss: 0.43961194157600403
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 28, Loss: 0.4318994879722595
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 29, Loss: 0.3685612678527832
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 30, Loss: 0.38313931226730347
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 31, Loss: 0.35389038920402527
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 32, Loss: 0.33778220415115356
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 33, Loss: 0.31569263339042664
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 34, Loss: 0.4780510663986206
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 35, Loss: 0.34674400091171265
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 36, Loss: 0.3610871136188507
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 37, Loss: 0.39378297328948975
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 38, Loss: 0.3792528808116913
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 39, Loss: 0.36911454796791077
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 40, Loss: 0.33913347125053406
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 41, Loss: 0.30901405215263367
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 42, Loss: 0.2955543100833893
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 43, Loss: 0.3163282573223114
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 44, Loss: 0.3141508400440216
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 45, Loss: 0.3331909477710724
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 46, Loss: 0.3029688894748688
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 47, Loss: 0.30271193385124207
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 48, Loss: 0.3126508593559265
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 49, Loss: 0.3153684437274933
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 50, Loss: 0.31728309392929077
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 51, Loss: 0.3278118968009949
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 52, Loss: 0.3074650466442108
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 53, Loss: 0.303009569644928
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 54, Loss: 0.30077001452445984
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 55, Loss: 0.3038135766983032
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 56, Loss: 0.3027859032154083
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 57, Loss: 0.30608728528022766
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 58, Loss: 0.3118782639503479
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 59, Loss: 0.29948922991752625
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 60, Loss: 0.3027649223804474
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 61, Loss: 0.3063877820968628
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 62, Loss: 0.3038838505744934
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 63, Loss: 0.30113378167152405
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 64, Loss: 0.29431554675102234
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 65, Loss: 0.2959432005882263
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 66, Loss: 0.2966013252735138
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 67, Loss: 0.30334460735321045
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 68, Loss: 0.3174135684967041
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 69, Loss: 0.3157457709312439
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 70, Loss: 0.3187078833580017
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 71, Loss: 0.31369391083717346
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 72, Loss: 0.296338826417923
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 73, Loss: 0.3063526451587677
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 74, Loss: 0.29605334997177124
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 75, Loss: 0.2991734445095062
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 76, Loss: 0.30241283774375916
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 77, Loss: 0.296967089176178
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 78, Loss: 0.2970588803291321
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 79, Loss: 0.30316418409347534
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 80, Loss: 0.32376745343208313
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 81, Loss: 0.2935084402561188
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 82, Loss: 0.29304268956184387
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 83, Loss: 0.30639150738716125
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 84, Loss: 0.29530853033065796
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 85, Loss: 0.2888678014278412
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 86, Loss: 0.2872258722782135
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 87, Loss: 0.2803017199039459
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 88, Loss: 0.2813636064529419
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 89, Loss: 0.28152087330818176
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 90, Loss: 0.27050912380218506
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 91, Loss: 0.2594088017940521
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 92, Loss: 0.25522828102111816
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 93, Loss: 0.24001279473304749
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 94, Loss: 0.2497306615114212
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 95, Loss: 0.21825328469276428
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 96, Loss: 0.19086113572120667
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 97, Loss: 0.188110813498497
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 98, Loss: 0.1948973536491394
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 99, Loss: 0.22055628895759583
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 809196])
# Epoch 100, Loss: 0.19927361607551575

# %% [markdown]
# ##### 量化指标呈现

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

y_true = np.array(x)  # 真实值
y_pred = np.array(rec_GIN)  # 预测值

mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true, y_pred)

print(f'均方误差（MSE）：{mse}')
print(f'均方根误差（RMSE）：{rmse}')
print(f'平均绝对误差（MAE）：{mae}')
# Out:
# 均方误差（MSE）：0.09943907707929611
# 均方根误差（RMSE）：0.3153396248817444
# 平均绝对误差（MAE）：0.25211626291275024

# %% [markdown]
# ### GAT

# %%
import os
import numpy as np
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
from scipy.sparse import csr_matrix
import networkx as nx

from scipy.linalg import orthogonal_procrustes

import torch
import torch.optim as optim
from torch_geometric.data import Data

from sklearn.manifold import TSNE
from sklearn.datasets import make_circles  # 导入make_moons函数

from util import Net, GIN, GAT, stationary, reconstruct, dG


np.random.seed(0)
torch.manual_seed(0)

n = 2000
m = 500

# 导入moon数据集
x, y = make_circles(n_samples=n, noise=0.1, random_state=42, factor=0.3) 
# 分割训练集和测试机
n_train = int(n * 0.7)
train_ind = torch.randperm(n)[:n_train]
test_ind = torch.LongTensor(list(set(np.arange(n)) - set(train_ind.tolist())))
# K = int(np.sqrt(n) * np.log2(n) / 10) #作为隐藏输入
D = pairwise_distances(x)# 邻接距离矩阵
# 二值化，得到邻接矩阵
A_binary = np.where(D <= DISTANCE, 1, 0)
# A_binary
# 获得所有的边，二元组格式
row_indices, col_indices = np.where(A_binary == 1)
edges = list(zip(row_indices, col_indices))

# 转为tensor
x = torch.tensor(x, dtype=torch.float)
y = torch.tensor(y, dtype=torch.long)
edges = torch.tensor(edges, dtype=torch.long).t().contiguous()
data = Data(x=x, y=y, edge_index=edges)
print(data)

# 喂到GAT网络中
net = GAT(m)
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.train()
for epoch in range(100):
    ind = torch.eye(n)[:, torch.randperm(n)[:m]]
    # 将节点选择矩阵与特征矩阵连接在一起
    X_extended = torch.hstack([x, ind])
    data = Data(x=X_extended, edge_index=edges)
    rec = net(data) # reconstruct
    loss = dG(x[train_ind], rec[train_ind]) #train loss
    print(f'Epoch {epoch + 1}, Loss: {float(loss)}')
    optimizer.zero_grad() # zero gradient
    loss.backward()
    optimizer.step()

R, _ = orthogonal_procrustes(x.numpy(), rec.detach().numpy())
rec_GAT = rec.detach().numpy() @ R.T
loss_GAT = float(dG(x, rec))
# 创建图形
fig, ax = plt.subplots(1, 2, figsize=(14, 4))
# ax两个画布
ax[0].scatter(x[:, 0], x[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_facecolor('#eeeeee')
txt = ax[0].text(0.05, 0.05, 'Ground Truth', color='k', fontsize=14, weight='bold', transform=ax[0].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='#eeeeee')])

# 绘制 GAT 网络的重构结果
ax[1].scatter(rec_GAT[:, 0], rec_GAT[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[1].set_xticks([])
ax[1].set_yticks([])
txt = ax[1].text(0.05, 0.05, f'GAT $d_G = {loss_GAT:.2f}$', color='k', fontsize=14, weight='bold', transform=ax[1].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='w')])

fig.subplots_adjust()

if not os.path.exists('imgs'):
    os.mkdir('imgs')

fig.savefig('imgs/semi_circle_GAT.png', bbox_inches='tight', dpi=300)

plt.show()
# Out:
# Data(x=[2000, 2], edge_index=[2, 809196], y=[2000])
# Epoch 1, Loss: 0.5510889291763306
# Epoch 2, Loss: 0.5510743260383606
# Epoch 3, Loss: 0.5510535836219788
# Epoch 4, Loss: 0.5510224103927612
# Epoch 5, Loss: 0.550963282585144
# Epoch 6, Loss: 0.5508697628974915
# Epoch 7, Loss: 0.5507168769836426
# Epoch 8, Loss: 0.5505064725875854
# Epoch 9, Loss: 0.5502110719680786
# Epoch 10, Loss: 0.5498190522193909
# Epoch 11, Loss: 0.5493146777153015
# Epoch 12, Loss: 0.5485829710960388
# Epoch 13, Loss: 0.5476440787315369
# Epoch 14, Loss: 0.5465549826622009
# Epoch 15, Loss: 0.5450085997581482
# Epoch 16, Loss: 0.5432286858558655
# Epoch 17, Loss: 0.5409145951271057
# Epoch 18, Loss: 0.5381118655204773
# Epoch 19, Loss: 0.5348204970359802
# Epoch 20, Loss: 0.5306581854820251
# Epoch 21, Loss: 0.526240348815918
# Epoch 22, Loss: 0.5209978222846985
# Epoch 23, Loss: 0.515023946762085
# Epoch 24, Loss: 0.5082941055297852
# Epoch 25, Loss: 0.4996355473995209
# Epoch 26, Loss: 0.490951806306839
# Epoch 27, Loss: 0.48134544491767883
# Epoch 28, Loss: 0.46954554319381714
# Epoch 29, Loss: 0.4580147862434387
# Epoch 30, Loss: 0.4449709951877594
# Epoch 31, Loss: 0.43109697103500366
# Epoch 32, Loss: 0.41534101963043213
# Epoch 33, Loss: 0.39794543385505676
# Epoch 34, Loss: 0.38139861822128296
# Epoch 35, Loss: 0.3624199628829956
# Epoch 36, Loss: 0.3444507420063019
# Epoch 37, Loss: 0.3256879150867462
# Epoch 38, Loss: 0.30426645278930664
# Epoch 39, Loss: 0.286185622215271
# Epoch 40, Loss: 0.2663595676422119
# Epoch 41, Loss: 0.2467179149389267
# Epoch 42, Loss: 0.23246464133262634
# Epoch 43, Loss: 0.2178703248500824
# Epoch 44, Loss: 0.20567777752876282
# Epoch 45, Loss: 0.19623951613903046
# Epoch 46, Loss: 0.1883847713470459
# Epoch 47, Loss: 0.18073004484176636
# Epoch 48, Loss: 0.1767616868019104
# Epoch 49, Loss: 0.1710197627544403
# Epoch 50, Loss: 0.16631539165973663
# Epoch 51, Loss: 0.15233507752418518
# Epoch 52, Loss: 0.14575964212417603
# Epoch 53, Loss: 0.13344420492649078
# Epoch 54, Loss: 0.11634038388729095
# Epoch 55, Loss: 0.1043028011918068
# Epoch 56, Loss: 0.09093354642391205
# Epoch 57, Loss: 0.08108963072299957
# Epoch 58, Loss: 0.07032529264688492
# Epoch 59, Loss: 0.06056844815611839
# Epoch 60, Loss: 0.055323295295238495
# Epoch 61, Loss: 0.04861697182059288
# Epoch 62, Loss: 0.04077931120991707
# Epoch 63, Loss: 0.03889423608779907
# Epoch 64, Loss: 0.038461100310087204
# Epoch 65, Loss: 0.03706609085202217
# Epoch 66, Loss: 0.03814690187573433
# Epoch 67, Loss: 0.03929838165640831
# Epoch 68, Loss: 0.04160783067345619
# Epoch 69, Loss: 0.04245734214782715
# Epoch 70, Loss: 0.04599384218454361
# Epoch 71, Loss: 0.04084615036845207
# Epoch 72, Loss: 0.04161352291703224
# Epoch 73, Loss: 0.04361109808087349
# Epoch 74, Loss: 0.04268145561218262
# Epoch 75, Loss: 0.04197930172085762
# Epoch 76, Loss: 0.04127953201532364
# Epoch 77, Loss: 0.04142211750149727
# Epoch 78, Loss: 0.03851059824228287
# Epoch 79, Loss: 0.03672565147280693
# Epoch 80, Loss: 0.037160567939281464
# Epoch 81, Loss: 0.03513913229107857
# Epoch 82, Loss: 0.03506194427609444
# Epoch 83, Loss: 0.03370238468050957
# Epoch 84, Loss: 0.03443947434425354
# Epoch 85, Loss: 0.0349472276866436
# Epoch 86, Loss: 0.035372380167245865
# Epoch 87, Loss: 0.03463434800505638
# Epoch 88, Loss: 0.03485448285937309
# Epoch 89, Loss: 0.034275930374860764
# Epoch 90, Loss: 0.03594544157385826
# Epoch 91, Loss: 0.035191021859645844
# Epoch 92, Loss: 0.03505075350403786
# Epoch 93, Loss: 0.034966304898262024
# Epoch 94, Loss: 0.03423934057354927
# Epoch 95, Loss: 0.03410892188549042
# Epoch 96, Loss: 0.034628964960575104
# Epoch 97, Loss: 0.033239152282476425
# Epoch 98, Loss: 0.03438197448849678
# Epoch 99, Loss: 0.033876653760671616
# Epoch 100, Loss: 0.0328543484210968

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

y_true = np.array(x)  # 真实值
y_pred = np.array(rec_GAT)  # 预测值

mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true, y_pred)

print(f'均方误差（MSE）：{mse}')
print(f'均方根误差（RMSE）：{rmse}')
print(f'平均绝对误差（MAE）：{mae}')
# Out:
# 均方误差（MSE）：0.01601695641875267
# 均方根误差（RMSE）：0.1265581101179123
# 平均绝对误差（MAE）：0.09679006040096283
