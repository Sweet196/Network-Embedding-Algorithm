# %% [markdown]
# ### Moon Dataset

# %%
# %matplotlib inline
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
from node import Node, Graph
import numpy as np

# 生成 make_moons 数据集
X, y = make_moons(n_samples=2000, noise=0.1
                  , random_state=42)
# X是每个点的坐标(x, y)，y是每个点的label
nodes = []
index = 0
for df, label in zip(X, y):
    nodes.append(Node(df, label, index))
    index += 1
# scatter
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title("moon_dataset visulization")
plt.show()

# %% [markdown]
# ### 构建邻接矩阵

# %%
DISTANCE = 0.5
graph = Graph(nodes, distance=DISTANCE)
adjacency_matrix = np.array(graph.get_adjacency_matrix())
print("邻接矩阵：", adjacency_matrix.shape)

#根据邻接矩阵获取所有的二元组，如：[(0, 1), (0, 2), (1, 2)]
edges = graph.get_edges()
print(f"Distance={DISTANCE}, 构建了{len(edges)}条边")
# Out:
# 邻接矩阵： (2000, 2000)
# Distance=0.5, 构建了289371条边

# %% [markdown]
# ### DeepWalk

# %% [markdown]
# #### Deepwalk策略定义

# %%
# deepwalk的游走策略
import networkx as nx
import gensim
import random

def deepwalk(graph, walk_length = 60, num_walks = 200, dim = 32):
    # 生成随机游走序列
    walks = []
    for _ in range(num_walks):
        node = random.choice(list(graph.nodes))
        walk = [node]
        while len(walk) < walk_length:
            neighbors = list(graph[node])
            next_node = neighbors[random.randint(0, len(neighbors) - 1)] if neighbors else node
            walk.append(next_node)
            node = next_node
        walks.append(walk)
    # print(walks, end = '\n')

    # 使用 gensim 的 Word2Vec 训练嵌入向量
    sentences = [list(map(str, walk)) for walk in walks]
    # for walk in walks:
    #     print(walk)
    # print(sentences)
    model = gensim.models.Word2Vec(sentences, vector_size=dim, window=walk_length, min_count=1, sg=1)
    node2vec = {str(node): model.wv[str(node)] if str(node) in model.wv else None for node in graph.nodes}
    # for node in graph.nodes:
        # print(node, model.wv[str(node)])
    return node2vec

# %% [markdown]
# #### Deepwalk嵌入，取两维简单做个可视化

# %%
nx = graph.to_nx()
# print(nx.nodes)
embeddings = deepwalk(nx)
# embeddings

# 随便取两个维度看看
x = [embedding[0] for embedding in list(embeddings.values()) if embedding is not None]
y = [embedding[1] for embedding in list(embeddings.values()) if embedding is not None]



label = [node.label for node in nodes if(embeddings[str(node.index)] is not None)]

# 创建散点图
plt.scatter(x, y, c=label)
plt.title("DeepWalk-Make_Moon_Embedding")
# 显示图形
plt.show()

# %% [markdown]
# #### PCA降维，降到两维后做可视化

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# 先drop掉None
embeddings = {key: value for key, value in embeddings.items() if value is not None}
# 假设embeddings是一个字典，其中包含嵌入值
embeddings_value = list(embeddings.values())

# 使用PCA进行降维
pca = PCA(n_components=2)
pca.fit(embeddings_value)
X_pca = pca.transform(embeddings_value)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=label)
plt.title("DeepWalk-Make_Moon_PCA")
plt.show()

# %% [markdown]
# ### Node2Vec

# %% [markdown]
# #### Node2Vec算法定义

# %%
import networkx as nx
import gensim
import random

def node2vec(graph, walk_length=60, num_walks=200, p=1.0, q=1.0, dim=32):
    # Generate random walk sequences
    walks = []
    for _ in range(num_walks):
        node = random.choice(list(graph.nodes))
        walk = [node]
        while len(walk) < walk_length:
            neighbors = list(graph.neighbors(node))
            if len(neighbors) > 0:
                if len(walk) == 1 or random.random() < p:
                    # Choose a neighbor at random with probability P
                    next_node = random.choice(neighbors)
                else:
                    # Choose a neighbor with probability proportional to the inverse of the square of the distance to the previous node
                    weights = [1.0 / q if n == walk[-1] else 1.0 for n in neighbors]
                    next_node = random.choices(neighbors, weights)[0]
                walk.append(next_node)
                node = next_node
            else:
                break
        walks.append(walk)

    # Use gensim's Word2Vec to train embedding vectors
    sentences = [list(map(str, walk)) for walk in walks]
    model = gensim.models.Word2Vec(sentences, vector_size=dim, window=walk_length, min_count=1, sg=1)
    node2vec = {str(node): model.wv[str(node)] if str(node) in model.wv else None for node in graph.nodes}
    return node2vec

# %%
nx = graph.to_nx()
# print(nx.nodes)
embeddings = node2vec(nx)
# embeddings

# 随便取两个维度看看
x = [embedding[0] for embedding in list(embeddings.values()) if embedding is not None]
y = [embedding[1] for embedding in list(embeddings.values()) if embedding is not None]



label = [node.label for node in nodes if(embeddings[str(node.index)] is not None)]

# 创建散点图
plt.scatter(x, y, c=label)
plt.title("Node2Vec-Make_Moon_Embedding")
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# 先drop掉None
embeddings = {key: value for key, value in embeddings.items() if value is not None}
# 假设embeddings是一个字典，其中包含嵌入值
embeddings_value = list(embeddings.values())

# 使用PCA进行降维
pca = PCA(n_components=2)
pca.fit(embeddings_value)
X_pca = pca.transform(embeddings_value)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=label)
plt.title("Node2Vec-Make_Moon_PCA")
plt.show()

# %% [markdown]
# #### GCN

# %%
import os
import numpy as np
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
from scipy.sparse import csr_matrix
import networkx as nx

from scipy.linalg import orthogonal_procrustes

import torch
import torch.optim as optim
from torch_geometric.data import Data

from sklearn.manifold import TSNE
from sklearn.datasets import make_moons  # 导入make_moons函数

from util import Net, GIN, GAT, stationary, reconstruct, dG, GCN


np.random.seed(0)
torch.manual_seed(0)

n = 2000
m = 500
DISTANCE = 0.1

# 导入moon数据集
x, y = make_moons(n_samples=n, noise=0.1, random_state=0) 
# 分割训练集和测试机
n_train = int(n * 0.7)
train_ind = torch.randperm(n)[:n_train]
test_ind = torch.LongTensor(list(set(np.arange(n)) - set(train_ind.tolist())))
# K = int(np.sqrt(n) * np.log2(n) / 10) #作为隐藏输入
D = pairwise_distances(x)# 邻接距离矩阵
# 二值化，得到邻接矩阵
A_binary = np.where(D <= DISTANCE, 1, 0)
# A_binary
# 获得所有的边，二元组格式
row_indices, col_indices = np.where(A_binary == 1)
edges = list(zip(row_indices, col_indices))

# 转为tensor
x = torch.tensor(x, dtype=torch.float)
y = torch.tensor(y, dtype=torch.long)
edges = torch.tensor(edges, dtype=torch.long).t().contiguous()
data = Data(x=x, y=y, edge_index=edges)
print(data)

# 喂到GCN网络中
net = GCN(m)
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.train()
for epoch in range(10):
    ind = torch.eye(n)[:, torch.randperm(n)[:m]]
    # 将节点选择矩阵与特征矩阵连接在一起
    X_extended = torch.hstack([x, ind]) # 
    data = Data(x=X_extended, edge_index=edges)
    rec = net(data) # reconstruct
    loss = dG(x[train_ind], rec[train_ind]) #train loss
    print(f'Epoch {epoch + 1}, Loss: {float(loss)}')
    optimizer.zero_grad() # zero gradient
    loss.backward()
    optimizer.step()

R, _ = orthogonal_procrustes(x.numpy(), rec.detach().numpy())
rec_GIN = rec.detach().numpy() @ R.T
loss_GIN = float(dG(x, rec))
# 创建图形
fig, ax = plt.subplots(1, 2, figsize=(14, 4))
# ax两个画布
ax[0].scatter(x[:, 0], x[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_facecolor('#eeeeee')
txt = ax[0].text(0.05, 0.05, 'Ground Truth', color='k', fontsize=14, weight='bold', transform=ax[0].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='#eeeeee')])

# 绘制 GIN 网络的重构结果
ax[1].scatter(rec_GIN[:, 0], rec_GIN[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[1].set_xticks([])
ax[1].set_yticks([])
txt = ax[1].text(0.05, 0.05, f'GCN $d_G = {loss_GIN:.2f}$', color='k', fontsize=14, weight='bold', transform=ax[1].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='w')])

fig.subplots_adjust()

if not os.path.exists('imgs'):
    os.mkdir('imgs')

fig.savefig('imgs/semi_moon_GCN.png', bbox_inches='tight', dpi=300)

plt.show()
# Out:
# Data(x=[2000, 2], edge_index=[2, 53372], y=[2000])
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 1, Loss: 1.1915305852890015
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 2, Loss: 1.172237753868103
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 3, Loss: 1.1434844732284546
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 4, Loss: 1.1122840642929077
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 5, Loss: 1.1002510786056519
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 6, Loss: 1.077022910118103
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 7, Loss: 1.052596926689148
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 8, Loss: 1.0368216037750244
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 9, Loss: 1.0144819021224976
# 拼接后的矩阵shape： torch.Size([2000, 502])
# Epoch 10, Loss: 0.9888842701911926

# %% [markdown]
# ### GIN

# %%
import os
import numpy as np
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
from scipy.sparse import csr_matrix
import networkx as nx

from scipy.linalg import orthogonal_procrustes

import torch
import torch.optim as optim
from torch_geometric.data import Data

from sklearn.manifold import TSNE
from sklearn.datasets import make_moons  # 导入make_moons函数

from util import Net, GIN, GAT, stationary, reconstruct, dG


np.random.seed(0)
torch.manual_seed(0)

n = 2000
m = 500
DISTANCE = 0.1

# 导入moon数据集
x, y = make_moons(n_samples=n, noise=0.1, random_state=0) 
# 分割训练集和测试机
n_train = int(n * 0.7)
train_ind = torch.randperm(n)[:n_train]
test_ind = torch.LongTensor(list(set(np.arange(n)) - set(train_ind.tolist())))
# K = int(np.sqrt(n) * np.log2(n) / 10) #作为隐藏输入
D = pairwise_distances(x)# 邻接距离矩阵
# 二值化，得到邻接矩阵
A_binary = np.where(D <= DISTANCE, 1, 0)
# A_binary
# 获得所有的边，二元组格式
row_indices, col_indices = np.where(A_binary == 1)
edges = list(zip(row_indices, col_indices))

# 转为tensor
x = torch.tensor(x, dtype=torch.float)
y = torch.tensor(y, dtype=torch.long)
edges = torch.tensor(edges, dtype=torch.long).t().contiguous()
data = Data(x=x, y=y, edge_index=edges)
print(data)

# 喂到GIN网络中
net = GIN(m)
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.train()
for epoch in range(100):
    ind = torch.eye(n)[:, torch.randperm(n)[:m]]
    # 将节点选择矩阵与特征矩阵连接在一起
    X_extended = torch.hstack([x, ind]) # 
    print("拼接后的矩阵shape：", X_extended.shape)
    data = Data(x=X_extended, edge_index=edges)
    rec = net(data) # reconstruct
    loss = dG(x[train_ind], rec[train_ind]) #train loss
    print(f'Epoch {epoch + 1}, Loss: {float(loss)}')
    optimizer.zero_grad() # zero gradient
    loss.backward()
    optimizer.step()

R, _ = orthogonal_procrustes(x.numpy(), rec.detach().numpy())
rec_GIN = rec.detach().numpy() @ R.T
loss_GIN = float(dG(x, rec))
# 创建图形
fig, ax = plt.subplots(1, 2, figsize=(14, 4))
# ax两个画布
ax[0].scatter(x[:, 0], x[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_facecolor('#eeeeee')
txt = ax[0].text(0.05, 0.05, 'Ground Truth', color='k', fontsize=14, weight='bold', transform=ax[0].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='#eeeeee')])

# 绘制 GIN 网络的重构结果
ax[1].scatter(rec_GIN[:, 0], rec_GIN[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[1].set_xticks([])
ax[1].set_yticks([])
txt = ax[1].text(0.05, 0.05, f'GIN $d_G = {loss_GIN:.2f}$', color='k', fontsize=14, weight='bold', transform=ax[1].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='w')])

fig.subplots_adjust()

if not os.path.exists('imgs'):
    os.mkdir('imgs')

fig.savefig('imgs/semi_moon_GIN.png', bbox_inches='tight', dpi=300)

plt.show()
# Out:
# Data(x=[2000, 2], edge_index=[2, 53372], y=[2000])
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 1, Loss: 1.2955381870269775
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 2, Loss: 1.282875418663025
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 3, Loss: 1.258018970489502
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 4, Loss: 1.21334969997406
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 5, Loss: 1.1331697702407837
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 6, Loss: 1.0149024724960327
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 7, Loss: 1.000179409980774
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 8, Loss: 0.9564490914344788
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 9, Loss: 0.8573702573776245
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 10, Loss: 0.8158190846443176
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 11, Loss: 0.7596456408500671
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 12, Loss: 0.6971806287765503
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 13, Loss: 0.6725828051567078
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 14, Loss: 0.5690099000930786
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 15, Loss: 0.5900775194168091
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 16, Loss: 0.5357030034065247
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 17, Loss: 0.506465494632721
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 18, Loss: 0.5472127199172974
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 19, Loss: 0.5391224026679993
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 20, Loss: 0.5298235416412354
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 21, Loss: 0.5081466436386108
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 22, Loss: 0.4974448084831238
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 23, Loss: 0.5069382786750793
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 24, Loss: 0.5107614994049072
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 25, Loss: 0.5051211714744568
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 26, Loss: 0.4914604425430298
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 27, Loss: 0.4998466670513153
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 28, Loss: 0.4923209846019745
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 29, Loss: 0.4865950345993042
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 30, Loss: 0.48459392786026
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 31, Loss: 0.4969918429851532
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 32, Loss: 0.4810601770877838
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 33, Loss: 0.4769834280014038
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 34, Loss: 0.4798215925693512
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 35, Loss: 0.4860893785953522
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 36, Loss: 0.48096463084220886
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 37, Loss: 0.4771389663219452
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 38, Loss: 0.4824332594871521
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 39, Loss: 0.480419397354126
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 40, Loss: 0.4718876779079437
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 41, Loss: 0.46566808223724365
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 42, Loss: 0.47266387939453125
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 43, Loss: 0.4718267023563385
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 44, Loss: 0.47073832154273987
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 45, Loss: 0.46574845910072327
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 46, Loss: 0.46579882502555847
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 47, Loss: 0.4686709940433502
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 48, Loss: 0.45885372161865234
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 49, Loss: 0.457660436630249
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 50, Loss: 0.4526289105415344
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 51, Loss: 0.44961830973625183
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 52, Loss: 0.44216907024383545
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 53, Loss: 0.4476396441459656
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 54, Loss: 0.44410645961761475
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 55, Loss: 0.4535283148288727
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 56, Loss: 0.44364240765571594
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 57, Loss: 0.4340856969356537
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 58, Loss: 0.46545636653900146
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 59, Loss: 0.4720507860183716
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 60, Loss: 0.44767245650291443
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 61, Loss: 0.48436376452445984
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 62, Loss: 0.4234050214290619
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 63, Loss: 0.4480748176574707
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 64, Loss: 0.4363982677459717
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 65, Loss: 0.41711586713790894
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 66, Loss: 0.4467056393623352
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 67, Loss: 0.41378894448280334
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 68, Loss: 0.42756927013397217
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 69, Loss: 0.41086283326148987
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 70, Loss: 0.4086077809333801
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 71, Loss: 0.4011710584163666
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 72, Loss: 0.3969363868236542
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 73, Loss: 0.39033934473991394
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 74, Loss: 0.3765767514705658
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 75, Loss: 0.35886088013648987
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 76, Loss: 0.3367465138435364
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 77, Loss: 0.33990034461021423
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 78, Loss: 0.3306228518486023
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 79, Loss: 0.31533747911453247
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 80, Loss: 0.2978789508342743
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 81, Loss: 0.2935953736305237
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 82, Loss: 0.2734867334365845
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 83, Loss: 0.28889867663383484
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 84, Loss: 0.28101271390914917
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 85, Loss: 0.2868111729621887
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 86, Loss: 0.28197556734085083
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 87, Loss: 0.2822208106517792
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 88, Loss: 0.2550602853298187
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 89, Loss: 0.26932835578918457
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 90, Loss: 0.255150705575943
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 91, Loss: 0.26173409819602966
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 92, Loss: 0.2498362511396408
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 93, Loss: 0.25194302201271057
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 94, Loss: 0.24446116387844086
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 95, Loss: 0.2354986071586609
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 96, Loss: 0.23438230156898499
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 97, Loss: 0.23105739057064056
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 98, Loss: 0.22520719468593597
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 99, Loss: 0.22604797780513763
# 拼接后的矩阵shape： torch.Size([2000, 502])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 53372])
# Epoch 100, Loss: 0.21481460332870483

# %% [markdown]
# ##### 量化指标呈现

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

y_true = np.array(x)  # 真实值
y_pred = np.array(rec_GIN)  # 预测值

mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true, y_pred)

print(f'均方误差（MSE）：{mse}')
print(f'均方根误差（RMSE）：{rmse}')
print(f'平均绝对误差（MAE）：{mae}')
# Out:
# 均方误差（MSE）：0.49792686104774475
# 均方根误差（RMSE）：0.7056393027305603
# 平均绝对误差（MAE）：0.5276138782501221

# %% [markdown]
# ### GAT

# %%
import os
import numpy as np
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
from scipy.sparse import csr_matrix
import networkx as nx

from scipy.linalg import orthogonal_procrustes

import torch
import torch.optim as optim
from torch_geometric.data import Data

from sklearn.manifold import TSNE
from sklearn.datasets import make_moons  # 导入make_moons函数

from util import Net, GIN, GAT, stationary, reconstruct, dG


np.random.seed(0)
torch.manual_seed(0)

n = 2000
m = 500

# 导入moon数据集
x, y = make_moons(n_samples=n, noise=0.1, random_state=0) 
# 分割训练集和测试机
n_train = int(n * 0.7)
train_ind = torch.randperm(n)[:n_train]
test_ind = torch.LongTensor(list(set(np.arange(n)) - set(train_ind.tolist())))
# K = int(np.sqrt(n) * np.log2(n) / 10) #作为隐藏输入
D = pairwise_distances(x)# 邻接距离矩阵
# 二值化，得到邻接矩阵
A_binary = np.where(D <= DISTANCE, 1, 0)
# A_binary
# 获得所有的边，二元组格式
row_indices, col_indices = np.where(A_binary == 1)
edges = list(zip(row_indices, col_indices))

# 转为tensor
x = torch.tensor(x, dtype=torch.float)
y = torch.tensor(y, dtype=torch.long)
edges = torch.tensor(edges, dtype=torch.long).t().contiguous()
data = Data(x=x, y=y, edge_index=edges)
print(data)

# 喂到GAT网络中
net = GAT(m)
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.train()
for epoch in range(10):
    ind = torch.eye(n)[:, torch.randperm(n)[:m]]
    # 将节点选择矩阵与特征矩阵连接在一起
    X_extended = torch.hstack([x, ind])
    data = Data(x=X_extended, edge_index=edges)
    rec = net(data) # reconstruct
    loss = dG(x[train_ind], rec[train_ind]) #train loss
    print(f'Epoch {epoch + 1}, Loss: {float(loss)}')
    optimizer.zero_grad() # zero gradient
    loss.backward()
    optimizer.step()

R, _ = orthogonal_procrustes(x.numpy(), rec.detach().numpy())
rec_GAT = rec.detach().numpy() @ R.T
loss_GAT = float(dG(x, rec))
# 创建图形
fig, ax = plt.subplots(1, 2, figsize=(14, 4))
# ax两个画布
ax[0].scatter(x[:, 0], x[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_facecolor('#eeeeee')
txt = ax[0].text(0.05, 0.05, 'Ground Truth', color='k', fontsize=14, weight='bold', transform=ax[0].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='#eeeeee')])

# 绘制 GAT 网络的重构结果
ax[1].scatter(rec_GAT[:, 0], rec_GAT[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[1].set_xticks([])
ax[1].set_yticks([])
txt = ax[1].text(0.05, 0.05, f'GAT $d_G = {loss_GAT:.2f}$', color='k', fontsize=14, weight='bold', transform=ax[1].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='w')])

fig.subplots_adjust()

if not os.path.exists('imgs'):
    os.mkdir('imgs')

fig.savefig('imgs/semi_moon_GAT.png', bbox_inches='tight', dpi=300)

plt.show()
# Out:
# Data(x=[2000, 2], edge_index=[2, 579986], y=[2000])
# Epoch 1, Loss: 1.3226933479309082
# Epoch 2, Loss: 1.3210535049438477
# Epoch 3, Loss: 1.3194568157196045
# Epoch 4, Loss: 1.3177460432052612
# Epoch 5, Loss: 1.315779447555542
# Epoch 6, Loss: 1.3135368824005127
# Epoch 7, Loss: 1.3108419179916382
# Epoch 8, Loss: 1.307729959487915
# Epoch 9, Loss: 1.304025411605835
# Epoch 10, Loss: 1.2997366189956665

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

y_true = np.array(x)  # 真实值
y_pred = np.array(rec_GAT)  # 预测值

mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true, y_pred)

print(f'均方误差（MSE）：{mse}')
print(f'均方根误差（RMSE）：{rmse}')
print(f'平均绝对误差（MAE）：{mae}')
# Out:
# 均方误差（MSE）：0.6541514992713928
# 均方根误差（RMSE）：0.8087963461875916
# 平均绝对误差（MAE）：0.6453352570533752
