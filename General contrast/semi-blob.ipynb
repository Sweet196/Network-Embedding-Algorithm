# %% [markdown]
# ### Blob Dataset

# %%
# %matplotlib inline
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from node import Node, Graph
import numpy as np

# 生成 make_moons 数据集
X, y = make_blobs(n_samples=2000, random_state=42, n_features=2,centers=30, cluster_std=0.8,
                  center_box=(-10.0,10.0))
# X是每个点的坐标(x, y)，y是每个点的label
nodes = []
index = 0
for df, label in zip(X, y):
    nodes.append(Node(df, label, index))
    index += 1
# scatter
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title("blob_dataset visulization")
plt.show()
X.shape, y.shape
# Out:
# ((2000, 2), (2000,))

# %% [markdown]
# ### 构建邻接矩阵

# %%
DISTANCE = 0.5
graph = Graph(nodes, distance=DISTANCE)
adjacency_matrix = np.array(graph.get_adjacency_matrix())
print("邻接矩阵：", adjacency_matrix.shape)

#根据邻接矩阵获取所有的二元组，如：[(0, 1), (0, 2), (1, 2)]
edges = graph.get_edges()
print(f"Distance={DISTANCE}, 构建了{len(edges)}条边")
# Out:
# 邻接矩阵： (2000, 2000)
# Distance=0.5, 构建了10011条边

# %% [markdown]
# ### DeepWalk

# %% [markdown]
# #### Deepwalk策略定义

# %%
# deepwalk的游走策略
import networkx as nx
import gensim
import random

def deepwalk(graph, walk_length = 60, num_walks = 200, dim = 32):
    # 生成随机游走序列
    walks = []
    for _ in range(num_walks):
        node = random.choice(list(graph.nodes))
        walk = [node]
        while len(walk) < walk_length:
            neighbors = list(graph[node])
            next_node = neighbors[random.randint(0, len(neighbors) - 1)] if neighbors else node
            walk.append(next_node)
            node = next_node
        walks.append(walk)
    # print(walks, end = '\n')

    # 使用 gensim 的 Word2Vec 训练嵌入向量
    sentences = [list(map(str, walk)) for walk in walks]
    # for walk in walks:
    #     print(walk)
    # print(sentences)
    model = gensim.models.Word2Vec(sentences, vector_size=dim, window=walk_length, min_count=1, sg=1)
    node2vec = {str(node): model.wv[str(node)] if str(node) in model.wv else None for node in graph.nodes}
    # for node in graph.nodes:
        # print(node, model.wv[str(node)])
    return node2vec

# %% [markdown]
# #### Deepwalk嵌入，取两维简单做个可视化

# %%
nx = graph.to_nx()
# print(nx.nodes)
embeddings = deepwalk(nx)
# embeddings

# 随便取两个维度看看
x = [embedding[0] for embedding in list(embeddings.values()) if embedding is not None]
y = [embedding[1] for embedding in list(embeddings.values()) if embedding is not None]



label = [node.label for node in nodes if(embeddings[str(node.index)] is not None)]

# 创建散点图
plt.scatter(x, y, c=label)
plt.title("DeepWalk-Make_Blob_Embedding")
# 显示图形
plt.show()

# %% [markdown]
# #### PCA降维，降到两维后做可视化

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# 先drop掉None
embeddings = {key: value for key, value in embeddings.items() if value is not None}
# 假设embeddings是一个字典，其中包含嵌入值
embeddings_value = list(embeddings.values())

# 使用PCA进行降维
pca = PCA(n_components=2)
pca.fit(embeddings_value)
X_pca = pca.transform(embeddings_value)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=label)
plt.title("DeepWalk-Make_Blob_PCA")
plt.show()

# %% [markdown]
# ### Node2Vec

# %% [markdown]
# #### Node2Vec算法定义

# %%
import networkx as nx
import gensim
import random

def node2vec(graph, walk_length=60, num_walks=200, p=1.0, q=1.0, dim=32):
    # Generate random walk sequences
    walks = []
    for _ in range(num_walks):
        node = random.choice(list(graph.nodes))
        walk = [node]
        while len(walk) < walk_length:
            neighbors = list(graph.neighbors(node))
            if len(neighbors) > 0:
                if len(walk) == 1 or random.random() < p:
                    # Choose a neighbor at random with probability P
                    next_node = random.choice(neighbors)
                else:
                    # Choose a neighbor with probability proportional to the inverse of the square of the distance to the previous node
                    weights = [1.0 / q if n == walk[-1] else 1.0 for n in neighbors]
                    next_node = random.choices(neighbors, weights)[0]
                walk.append(next_node)
                node = next_node
            else:
                break
        walks.append(walk)

    # Use gensim's Word2Vec to train embedding vectors
    sentences = [list(map(str, walk)) for walk in walks]
    model = gensim.models.Word2Vec(sentences, vector_size=dim, window=walk_length, min_count=1, sg=1)
    node2vec = {str(node): model.wv[str(node)] if str(node) in model.wv else None for node in graph.nodes}
    return node2vec

# %%
nx = graph.to_nx()
# print(nx.nodes)
embeddings = node2vec(nx)
# embeddings

# 随便取两个维度看看
x = [embedding[0] for embedding in list(embeddings.values()) if embedding is not None]
y = [embedding[1] for embedding in list(embeddings.values()) if embedding is not None]



label = [node.label for node in nodes if(embeddings[str(node.index)] is not None)]

# 创建散点图
plt.scatter(x, y, c=label)
plt.title("Node2Vec-Make_Blob_Embedding")
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# 先drop掉None
embeddings = {key: value for key, value in embeddings.items() if value is not None}
# 假设embeddings是一个字典，其中包含嵌入值
embeddings_value = list(embeddings.values())

# 使用PCA进行降维
pca = PCA(n_components=2)
pca.fit(embeddings_value)
X_pca = pca.transform(embeddings_value)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=label)
plt.title("Node2Vec-Make_Blob_PCA")
plt.show()

# %% [markdown]
# ### GIN

# %%
import os
import numpy as np
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
from scipy.sparse import csr_matrix
import networkx as nx

from scipy.linalg import orthogonal_procrustes

import torch
import torch.optim as optim
from torch_geometric.data import Data

from sklearn.manifold import TSNE
from sklearn.datasets import make_blobs  # 导入make_moons函数

from util import Net, GIN, GAT, stationary, reconstruct, dG


np.random.seed(0)
torch.manual_seed(0)

n = 2000
m = 500

# 导入moon数据集
x, y = make_blobs(n_samples=2000, random_state=42, n_features=2,centers=30, cluster_std=0.8,
                  center_box=(-10.0,10.0))
# 分割训练集和测试机
n_train = int(n * 0.7)
train_ind = torch.randperm(n)[:n_train]
test_ind = torch.LongTensor(list(set(np.arange(n)) - set(train_ind.tolist())))
# K = int(np.sqrt(n) * np.log2(n) / 10) #作为隐藏输入
D = pairwise_distances(x)# 邻接距离矩阵
# 二值化，得到邻接矩阵
A_binary = np.where(D <= DISTANCE, 1, 0)
# A_binary
# 获得所有的边，二元组格式
row_indices, col_indices = np.where(A_binary == 1)
edges = list(zip(row_indices, col_indices))

# 转为tensor
x = torch.tensor(x, dtype=torch.float)
y = torch.tensor(y, dtype=torch.long)
edges = torch.tensor(edges, dtype=torch.long).t().contiguous()
data = Data(x=x, y=y, edge_index=edges)
print(data)

# 喂到GIN网络中
net = GIN(m)
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.train()
for epoch in range(100):
    ind = torch.eye(n)[:, torch.randperm(n)[:m]]
    # 将节点选择矩阵与特征矩阵连接在一起
    X_extended = torch.hstack([x, ind])
    data = Data(x=X_extended, edge_index=edges)
    rec = net(data) # reconstruct
    loss = dG(x[train_ind], rec[train_ind]) #train loss
    print(f'Epoch {epoch + 1}, Loss: {float(loss)}')
    optimizer.zero_grad() # zero gradient
    loss.backward()
    optimizer.step()

R, _ = orthogonal_procrustes(x.numpy(), rec.detach().numpy())
rec_GIN = rec.detach().numpy() @ R.T
loss_GIN = float(dG(x, rec))
# 创建图形
fig, ax = plt.subplots(1, 2, figsize=(14, 4))
# ax两个画布
ax[0].scatter(x[:, 0], x[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_facecolor('#eeeeee')
txt = ax[0].text(0.05, 0.05, 'Ground Truth', color='k', fontsize=14, weight='bold', transform=ax[0].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='#eeeeee')])

# 绘制 GIN 网络的重构结果
ax[1].scatter(rec_GIN[:, 0], rec_GIN[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[1].set_xticks([])
ax[1].set_yticks([])
txt = ax[1].text(0.05, 0.05, f'GIN $d_G = {loss_GIN:.2f}$', color='k', fontsize=14, weight='bold', transform=ax[1].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='w')])

fig.subplots_adjust()

if not os.path.exists('imgs'):
    os.mkdir('imgs')

fig.savefig('imgs/semi_blob_GIN.png', bbox_inches='tight', dpi=300)

plt.show()
# Out:
# Data(x=[2000, 2], edge_index=[2, 22022], y=[2000])
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 1, Loss: 75.13790130615234
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 2, Loss: 75.1053695678711
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 3, Loss: 75.05137634277344
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 4, Loss: 74.93719482421875
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 5, Loss: 74.63990020751953
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 6, Loss: 73.78913116455078
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 7, Loss: 71.54096221923828
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 8, Loss: 66.93236541748047
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 9, Loss: 61.17538070678711
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 10, Loss: 73.16280364990234
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 11, Loss: 61.830135345458984
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 12, Loss: 58.836814880371094
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 13, Loss: 59.500701904296875
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 14, Loss: 61.572410583496094
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 15, Loss: 63.65218734741211
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 16, Loss: 63.003173828125
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 17, Loss: 62.32862854003906
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 18, Loss: 61.84089660644531
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 19, Loss: 60.65824890136719
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 20, Loss: 58.80335235595703
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 21, Loss: 56.78804016113281
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 22, Loss: 55.75015640258789
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 23, Loss: 57.77406311035156
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 24, Loss: 58.82400131225586
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 25, Loss: 56.77156066894531
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 26, Loss: 55.24335479736328
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 27, Loss: 55.147483825683594
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 28, Loss: 56.022361755371094
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 29, Loss: 56.60055923461914
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 30, Loss: 56.60342025756836
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 31, Loss: 56.138912200927734
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 32, Loss: 55.2013053894043
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 33, Loss: 54.983516693115234
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 34, Loss: 54.768829345703125
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 35, Loss: 54.874263763427734
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 36, Loss: 55.31600570678711
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 37, Loss: 55.089195251464844
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 38, Loss: 54.32406234741211
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 39, Loss: 54.27548599243164
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 40, Loss: 54.49498748779297
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 41, Loss: 54.58369445800781
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 42, Loss: 54.531986236572266
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 43, Loss: 54.017906188964844
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 44, Loss: 53.96725845336914
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 45, Loss: 53.376075744628906
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 46, Loss: 53.8220329284668
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 47, Loss: 54.011898040771484
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 48, Loss: 53.46965789794922
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 49, Loss: 53.12615966796875
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 50, Loss: 53.21350860595703
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 51, Loss: 53.06674575805664
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 52, Loss: 53.10420227050781
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 53, Loss: 52.772159576416016
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 54, Loss: 52.95457077026367
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 55, Loss: 52.54655838012695
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 56, Loss: 52.60807418823242
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 57, Loss: 52.372989654541016
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 58, Loss: 52.19279098510742
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 59, Loss: 51.9277458190918
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 60, Loss: 51.86592483520508
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 61, Loss: 51.867645263671875
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 62, Loss: 51.71969985961914
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 63, Loss: 51.52556228637695
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 64, Loss: 51.33815383911133
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 65, Loss: 51.264347076416016
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 66, Loss: 51.39640808105469
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 67, Loss: 51.199798583984375
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 68, Loss: 51.037052154541016
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 69, Loss: 50.93941879272461
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 70, Loss: 50.8956413269043
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 71, Loss: 50.66163635253906
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 72, Loss: 50.61324691772461
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 73, Loss: 50.735294342041016
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 74, Loss: 50.47282791137695
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 75, Loss: 50.457576751708984
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 76, Loss: 50.19329833984375
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 77, Loss: 50.22417449951172
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 78, Loss: 50.079833984375
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 79, Loss: 50.03960418701172
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 80, Loss: 49.771629333496094
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 81, Loss: 49.538963317871094
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 82, Loss: 49.323822021484375
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 83, Loss: 49.24784469604492
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 84, Loss: 49.015804290771484
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 85, Loss: 48.56201934814453
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 86, Loss: 48.622371673583984
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 87, Loss: 48.14090347290039
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 88, Loss: 47.895992279052734
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 89, Loss: 46.82632064819336
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 90, Loss: 47.06941223144531
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 91, Loss: 45.615177154541016
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 92, Loss: 44.0478515625
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 93, Loss: 43.31576919555664
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 94, Loss: 41.92346954345703
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 95, Loss: 41.03105163574219
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 96, Loss: 40.2706298828125
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 97, Loss: 40.60219955444336
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 98, Loss: 38.16643524169922
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 99, Loss: 37.020896911621094
# 输入形状: torch.Size([2000, 502]) torch.Size([2, 22022])
# Epoch 100, Loss: 36.15635681152344

# %% [markdown]
# ##### 量化指标呈现

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

y_true = np.array(x)  # 真实值
y_pred = np.array(rec_GIN)  # 预测值

mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true, y_pred)

print(f'均方误差（MSE）：{mse}')
print(f'均方根误差（RMSE）：{rmse}')
print(f'平均绝对误差（MAE）：{mae}')
# Out:
# 均方误差（MSE）：17.991071701049805
# 均方根误差（RMSE）：4.241588115692139
# 平均绝对误差（MAE）：3.4414656162261963

# %% [markdown]
# ### GAT

# %%
import os
import numpy as np
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
from scipy.sparse import csr_matrix
import networkx as nx

from scipy.linalg import orthogonal_procrustes

import torch
import torch.optim as optim
from torch_geometric.data import Data

from sklearn.manifold import TSNE
from sklearn.datasets import make_blobs  # 导入make_moons函数

from util import Net, GIN, GAT, stationary, reconstruct, dG


np.random.seed(0)
torch.manual_seed(0)

n = 2000
m = 500

# 导入moon数据集
x, y = make_blobs(n_samples=2000, random_state=42, n_features=2,centers=30, cluster_std=0.8,
                  center_box=(-10.0,10.0))
# 分割训练集和测试机
n_train = int(n * 0.7)
train_ind = torch.randperm(n)[:n_train]
test_ind = torch.LongTensor(list(set(np.arange(n)) - set(train_ind.tolist())))
# K = int(np.sqrt(n) * np.log2(n) / 10) #作为隐藏输入
D = pairwise_distances(x)# 邻接距离矩阵
# 二值化，得到邻接矩阵
A_binary = np.where(D <= DISTANCE, 1, 0)
# A_binary
# 获得所有的边，二元组格式
row_indices, col_indices = np.where(A_binary == 1)
edges = list(zip(row_indices, col_indices))

# 转为tensor
x = torch.tensor(x, dtype=torch.float)
y = torch.tensor(y, dtype=torch.long)
edges = torch.tensor(edges, dtype=torch.long).t().contiguous()
data = Data(x=x, y=y, edge_index=edges)
print(data)

# 喂到GAT网络中
net = GAT(m)
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.train()
for epoch in range(100):
    ind = torch.eye(n)[:, torch.randperm(n)[:m]]
    # 将节点选择矩阵与特征矩阵连接在一起
    X_extended = torch.hstack([x, ind])
    data = Data(x=X_extended, edge_index=edges)
    rec = net(data) # reconstruct
    loss = dG(x[train_ind], rec[train_ind]) #train loss
    print(f'Epoch {epoch + 1}, Loss: {float(loss)}')
    optimizer.zero_grad() # zero gradient
    loss.backward()
    optimizer.step()

R, _ = orthogonal_procrustes(x.numpy(), rec.detach().numpy())
rec_GAT = rec.detach().numpy() @ R.T
loss_GAT = float(dG(x, rec))
# 创建图形
fig, ax = plt.subplots(1, 2, figsize=(14, 4))
# ax两个画布
ax[0].scatter(x[:, 0], x[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_facecolor('#eeeeee')
txt = ax[0].text(0.05, 0.05, 'Ground Truth', color='k', fontsize=14, weight='bold', transform=ax[0].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='#eeeeee')])

# 绘制 GAT 网络的重构结果
ax[1].scatter(rec_GAT[:, 0], rec_GAT[:, 1], c=y, s=10, cmap='viridis', rasterized=True)
ax[1].set_xticks([])
ax[1].set_yticks([])
txt = ax[1].text(0.05, 0.05, f'GAT $d_G = {loss_GAT:.2f}$', color='k', fontsize=14, weight='bold', transform=ax[1].transAxes)
txt.set_path_effects([PathEffects.withStroke(linewidth=5, foreground='w')])

fig.subplots_adjust()

if not os.path.exists('imgs'):
    os.mkdir('imgs')

fig.savefig('imgs/semi_blob_GAT.png', bbox_inches='tight', dpi=300)

plt.show()
# Out:
# Data(x=[2000, 2], edge_index=[2, 22022], y=[2000])
# Epoch 1, Loss: 75.225830078125
# Epoch 2, Loss: 75.22014617919922
# Epoch 3, Loss: 75.21290588378906
# Epoch 4, Loss: 75.20274353027344
# Epoch 5, Loss: 75.18804931640625
# Epoch 6, Loss: 75.16722106933594
# Epoch 7, Loss: 75.13764190673828
# Epoch 8, Loss: 75.09774017333984
# Epoch 9, Loss: 75.04409790039062
# Epoch 10, Loss: 74.97364044189453
# Epoch 11, Loss: 74.8814926147461
# Epoch 12, Loss: 74.77266693115234
# Epoch 13, Loss: 74.62178802490234
# Epoch 14, Loss: 74.4549560546875
# Epoch 15, Loss: 74.23236083984375
# Epoch 16, Loss: 73.98849487304688
# Epoch 17, Loss: 73.66851043701172
# Epoch 18, Loss: 73.31511688232422
# Epoch 19, Loss: 72.89385223388672
# Epoch 20, Loss: 72.39817810058594
# Epoch 21, Loss: 71.79645538330078
# Epoch 22, Loss: 71.15506744384766
# Epoch 23, Loss: 70.44270324707031
# Epoch 24, Loss: 69.61093139648438
# Epoch 25, Loss: 68.57872009277344
# Epoch 26, Loss: 67.52750396728516
# Epoch 27, Loss: 66.32393646240234
# Epoch 28, Loss: 64.87322998046875
# Epoch 29, Loss: 63.4571533203125
# Epoch 30, Loss: 61.823699951171875
# Epoch 31, Loss: 60.10239791870117
# Epoch 32, Loss: 58.18905258178711
# Epoch 33, Loss: 56.02069091796875
# Epoch 34, Loss: 53.94854736328125
# Epoch 35, Loss: 51.1707878112793
# Epoch 36, Loss: 48.963218688964844
# Epoch 37, Loss: 45.78829574584961
# Epoch 38, Loss: 43.55264663696289
# Epoch 39, Loss: 40.22077178955078
# Epoch 40, Loss: 37.33184814453125
# Epoch 41, Loss: 34.18526840209961
# Epoch 42, Loss: 30.93509292602539
# Epoch 43, Loss: 27.560359954833984
# Epoch 44, Loss: 24.66253089904785
# Epoch 45, Loss: 22.033323287963867
# Epoch 46, Loss: 19.370784759521484
# Epoch 47, Loss: 17.100811004638672
# Epoch 48, Loss: 15.002419471740723
# Epoch 49, Loss: 13.11348819732666
# Epoch 50, Loss: 11.91514778137207
# Epoch 51, Loss: 10.663359642028809
# Epoch 52, Loss: 9.503664016723633
# Epoch 53, Loss: 8.482036590576172
# Epoch 54, Loss: 7.404708385467529
# Epoch 55, Loss: 6.153828144073486
# Epoch 56, Loss: 5.177101135253906
# Epoch 57, Loss: 4.5900959968566895
# Epoch 58, Loss: 3.8992843627929688
# Epoch 59, Loss: 3.716428518295288
# Epoch 60, Loss: 3.431997060775757
# Epoch 61, Loss: 4.042751312255859
# Epoch 62, Loss: 4.16619348526001
# Epoch 63, Loss: 4.120593070983887
# Epoch 64, Loss: 4.361999988555908
# Epoch 65, Loss: 3.967928409576416
# Epoch 66, Loss: 4.051934719085693
# Epoch 67, Loss: 3.7964460849761963
# Epoch 68, Loss: 3.4350969791412354
# Epoch 69, Loss: 2.9823081493377686
# Epoch 70, Loss: 2.8353805541992188
# Epoch 71, Loss: 2.5245144367218018
# Epoch 72, Loss: 2.7725906372070312
# Epoch 73, Loss: 2.0599186420440674
# Epoch 74, Loss: 2.248430013656616
# Epoch 75, Loss: 2.050032377243042
# Epoch 76, Loss: 1.9398430585861206
# Epoch 77, Loss: 1.7389642000198364
# Epoch 78, Loss: 1.9624836444854736
# Epoch 79, Loss: 1.728868007659912
# Epoch 80, Loss: 1.938172459602356
# Epoch 81, Loss: 1.6961324214935303
# Epoch 82, Loss: 1.6703472137451172
# Epoch 83, Loss: 1.8345413208007812
# Epoch 84, Loss: 1.5996816158294678
# Epoch 85, Loss: 1.6444876194000244
# Epoch 86, Loss: 1.7386127710342407
# Epoch 87, Loss: 1.750760793685913
# Epoch 88, Loss: 1.670668601989746
# Epoch 89, Loss: 1.64625084400177
# Epoch 90, Loss: 1.6378713846206665
# Epoch 91, Loss: 1.4085464477539062
# Epoch 92, Loss: 1.540311336517334
# Epoch 93, Loss: 1.5311625003814697
# Epoch 94, Loss: 1.5338839292526245
# Epoch 95, Loss: 1.4551010131835938
# Epoch 96, Loss: 1.3681644201278687
# Epoch 97, Loss: 1.6300972700119019
# Epoch 98, Loss: 1.582686185836792
# Epoch 99, Loss: 1.6119602918624878
# Epoch 100, Loss: 1.3622536659240723

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, mean_absolute_error

y_true = np.array(x)  # 真实值
y_pred = np.array(rec_GAT)  # 预测值

mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true, y_pred)

print(f'均方误差（MSE）：{mse}')
print(f'均方根误差（RMSE）：{rmse}')
print(f'平均绝对误差（MAE）：{mae}')
# Out:
# 均方误差（MSE）：0.6620957851409912
# 均方根误差（RMSE）：0.8136926889419556
# 平均绝对误差（MAE）：0.5769292116165161
