# %%
import json
from matplotlib import pyplot as plt

with open('./analysis/network_analysis_results_GCN.json', 'r') as file:
    results = json.load(file)
plt.figure(figsize=(10, 5))
epsilons = []
accuracies = []
for eps, res in results.items():
    epsilons.append(float(eps))
    accuracies.append(res['accuracy'])
plt.scatter(epsilons, accuracies, color='blue')
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epsilon')
plt.grid(True)
plt.savefig("./analysis/accuracy_vs_epsilon_GCN.png")
plt.show()

# %%
import json
from matplotlib import pyplot as plt
import numpy as np

# Load results from a JSON file
with open('./analysis/network_analysis_results_GCN.json', 'r') as file:
    results = json.load(file)

plt.figure(figsize=(10, 5))

# Prepare lists for plotting
epss = []
res_acc = []
res_degree = []
res_num_component = []
res_component_size1 = []# the max component size
res_component_size2 = []# the second_large component size

# Extract data from results
for eps, res in sorted(results.items(), key=lambda x: float(x[0])):  # Ensure the keys are sorted numerically
    if(len(res['component_sizes'])==1):
        break
    epss.append(float(eps))  # Convert eps to float for numerical plotting
    res_degree.append(res['average_degree'])
    res_num_component.append(res['num_components'])
    # Assuming res['component_sizes'] is a list, we could plot its average size
    res_component_size1.append(res['component_sizes'][0])  # Example: calculating the mean of component sizes
    res_component_size2.append(res['component_sizes'][1])  # Example: calculating the mean of component sizes

# Plotting
plt.plot(epss, res_degree, label='Average Degree')
plt.plot(epss, res_num_component, label='Number of Components')
plt.plot(epss, res_component_size1, label='Largest Component Size')  # Now plotting the average component size
plt.plot(epss, res_component_size2, label='Second-Largest Component Size')  # Now plotting the average component size

# Setup legend and labels
plt.legend(loc='upper right')
plt.xlabel('Epsilon')
plt.ylabel('Values')
# plt.xticks(np.arange(0, 3.6, 0.2))  # Ensure this range makes sense for your data

# Set grid visibility
plt.grid(True)

# Save the figure
plt.savefig("./analysis/analysis_epsilon_GCN.png")

# Display the plot
plt.show()
# %%

# %%
import json
from matplotlib import pyplot as plt

with open('./analysis/network_analysis_results_GIN.json', 'r') as file:
    results = json.load(file)
plt.figure(figsize=(10, 5))
epsilons = []
accuracies = []
for eps, res in results.items():
    epsilons.append(float(eps))
    accuracies.append(res['accuracy'])
plt.scatter(epsilons, accuracies, color='blue')
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epsilon')
plt.grid(True)
plt.savefig("./analysis/accuracy_vs_epsilon_GIN.png")
plt.show()

# %%
import json
from matplotlib import pyplot as plt
import numpy as np

# Load results from a JSON file
with open('./analysis/network_analysis_results_GIN.json', 'r') as file:
    results = json.load(file)

plt.figure(figsize=(10, 5))

# Prepare lists for plotting
epss = []
res_acc = []
res_degree = []
res_num_component = []
res_component_size1 = []# the max component size
res_component_size2 = []# the second_large component size

# Extract data from results
for eps, res in sorted(results.items(), key=lambda x: float(x[0])):  # Ensure the keys are sorted numerically
    if(len(res['component_sizes'])==1):
        break
    epss.append(float(eps))  # Convert eps to float for numerical plotting
    res_degree.append(res['average_degree'])
    res_num_component.append(res['num_components'])
    # Assuming res['component_sizes'] is a list, we could plot its average size
    res_component_size1.append(res['component_sizes'][0])  # Example: calculating the mean of component sizes
    res_component_size2.append(res['component_sizes'][1])  # Example: calculating the mean of component sizes

# Plotting
plt.plot(epss, res_degree, label='Average Degree')
plt.plot(epss, res_num_component, label='Number of Components')
plt.plot(epss, res_component_size1, label='Largest Component Size')  # Now plotting the average component size
plt.plot(epss, res_component_size2, label='Second-Largest Component Size')  # Now plotting the average component size

# Setup legend and labels
plt.legend(loc='upper right')
plt.xlabel('Epsilon')
plt.ylabel('Values')
# plt.xticks(np.arange(0, 3.6, 0.2))  # Ensure this range makes sense for your data

# Set grid visibility
plt.grid(True)

# Save the figure
plt.savefig("./analysis/analysis_epsilon_GIN.png")

# Display the plot
plt.show()
# %%

# %%
import json
from matplotlib import pyplot as plt

with open('./analysis/network_analysis_results_GAT.json', 'r') as file:
    results = json.load(file)
plt.figure(figsize=(10, 5))
epsilons = []
accuracies = []
for eps, res in results.items():
    epsilons.append(float(eps))
    accuracies.append(res['accuracy'])
plt.scatter(epsilons, accuracies, color='blue')
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epsilon')
plt.grid(True)
plt.savefig("./analysis/accuracy_vs_epsilon_GAT.png")
plt.show()

# %%
import json
from matplotlib import pyplot as plt
import numpy as np

# Load results from a JSON file
with open('./analysis/network_analysis_results_GAT.json', 'r') as file:
    results = json.load(file)

plt.figure(figsize=(10, 5))

# Prepare lists for plotting
epss = []
res_acc = []
res_degree = []
res_num_component = []
res_component_size1 = []# the max component size
res_component_size2 = []# the second_large component size

# Extract data from results
for eps, res in sorted(results.items(), key=lambda x: float(x[0])):  # Ensure the keys are sorted numerically
    if(len(res['component_sizes'])==1):
        break
    epss.append(float(eps))  # Convert eps to float for numerical plotting
    res_degree.append(res['average_degree'])
    res_num_component.append(res['num_components'])
    # Assuming res['component_sizes'] is a list, we could plot its average size
    res_component_size1.append(res['component_sizes'][0])  # Example: calculating the mean of component sizes
    res_component_size2.append(res['component_sizes'][1])  # Example: calculating the mean of component sizes

# Plotting
plt.plot(epss, res_degree, label='Average Degree')
plt.plot(epss, res_num_component, label='Number of Components')
plt.plot(epss, res_component_size1, label='Largest Component Size')  # Now plotting the average component size
plt.plot(epss, res_component_size2, label='Second-Largest Component Size')  # Now plotting the average component size

# Setup legend and labels
plt.legend(loc='upper right')
plt.xlabel('Epsilon')
plt.ylabel('Values')
# plt.xticks(np.arange(0, 3.6, 0.2))  # Ensure this range makes sense for your data

# Set grid visibility
plt.grid(True)

# Save the figure
plt.savefig("./analysis/analysis_epsilon_GAT.png")

# Display the plot
plt.show()
# %%

# %%
import json
import matplotlib.pyplot as plt

with open('./analysis/network_analysis_results_GCN.json', 'r') as file:
    results = json.load(file)

accuracies = []
for eps, res in results.items():
    accuracies.append(res['accuracy'])

plt.figure(figsize=(10, 5))
plt.boxplot(accuracies)
plt.xticks([1], ['Accuracy'])
plt.ylabel('Accuracy')
plt.title('Box Plot of Accuracy for Different Epsilon Values')
plt.grid(True)
plt.savefig("./analysis/accuracy_boxplot_GCN.png")
plt.show()
